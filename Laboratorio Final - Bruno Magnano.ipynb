# %% [markdown]
# # Laboratorio 2: Armado de un esquema de aprendizaje automático
#
# En el laboratorio final se espera que puedan poner en práctica los conocimientos adquiridos en el curso, trabajando con un conjunto de datos de clasificación.
#
# El objetivo es que se introduzcan en el desarrollo de un esquema para hacer tareas de aprendizaje automático: selección de un modelo, ajuste de hiperparámetros y evaluación.
#
# El conjunto de datos a utilizar está en `./data/loan_data.csv`. Si abren el archivo verán que al principio (las líneas que empiezan con `#`) describen el conjunto de datos y sus atributos (incluyendo el atributo de etiqueta o clase).
#
# Se espera que hagan uso de las herramientas vistas en el curso. Se espera que hagan uso especialmente de las herramientas brindadas por `scikit-learn`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.datasets import load_wine
from ml.visualization import plot_confusion_matrix, plot_learning_curve
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

np.random.seed(0)  # Para mayor determinismo

# %% [markdown]
# ## Carga de datos
#
# La celda siguiente se encarga de la carga de datos (haciendo uso de pandas). Estos serán los que se trabajarán en el resto del laboratorio.

# %%
dataset = pd.read_csv("./data/loan_data.csv", comment="#")
display(dataset.head())
# Out:
#    TARGET   LOAN  MORTDUE     VALUE   YOJ  DEROG  DELINQ       CLAGE  NINQ  \
# 0       0   4700  88026.0  115506.0   6.0    0.0     0.0  182.248332   0.0
# 1       0  19300  39926.0  101208.0   4.0    0.0     0.0  140.051638   0.0
# 2       0   5700  71556.0   79538.0   2.0    0.0     0.0   92.643085   0.0
# 3       0  13000  44875.0   57713.0   0.0    1.0     0.0  184.990324   1.0
# 4       0  19300  72752.0  106084.0  11.0    0.0     0.0  193.707100   1.0
#
#    CLNO    DEBTINC
# 0  27.0  29.209023
# 1  14.0  31.545694
# 2  15.0  41.210012
# 3  12.0  28.602076
# 4  13.0  30.686106

# %%
print('\nLongitud del dataset: '+str(len(dataset))+'\n')

#División entre instancias y etiquetas
X, y = dataset.drop(columns=['TARGET']), dataset.TARGET

print('Dataset:')
display(X.head())

print('Target:')
display(y.head())

print('Frecuencias del Target')
display(dataset.TARGET.value_counts())
# Out:
# Longitud del dataset: 1854
#
# Dataset:
#     LOAN  MORTDUE     VALUE   YOJ  DEROG  DELINQ       CLAGE  NINQ  CLNO  \
# 0   4700  88026.0  115506.0   6.0    0.0     0.0  182.248332   0.0  27.0
# 1  19300  39926.0  101208.0   4.0    0.0     0.0  140.051638   0.0  14.0
# 2   5700  71556.0   79538.0   2.0    0.0     0.0   92.643085   0.0  15.0
# 3  13000  44875.0   57713.0   0.0    1.0     0.0  184.990324   1.0  12.0
# 4  19300  72752.0  106084.0  11.0    0.0     0.0  193.707100   1.0  13.0
#
#      DEBTINC
# 0  29.209023
# 1  31.545694
# 2  41.210012
# 3  28.602076
# 4  30.686106
# Target:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: TARGET, dtype: int64
# Frecuencias del Target
# 0    1545
# 1     309
# Name: TARGET, dtype: int64

# %% [markdown]
# ## Ejercicio 1: División de datos en conjuntos de entrenamiento y evaluación
#
# La primer tarea consiste en dividir el conjunto de datos cargados en el apartado anterior en conjuntos de entrenamiento (o *training*) y evaluación (o *test*).
#
# El primero será utilizado para la creación/selección del modelo de clasificación. El segundo se utilizará sólo al final (una vez elegidos los mejores hiperparámetros) para ver cuál es el resultado final del modelo sobre un conjunto de datos independiente.

# %%
# TODO: Dividir en datos de entrenamiento y evaluación, 70% para entrenamiento y 30% para validación
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.30, random_state = 0)

# Para poder hacer un regresor por cada feature
feature_map = {feature: idx for idx, feature in enumerate(['LOAN', 'MORTDUE','VALUE','YOJ','DEROG','DELINQ', 
                                                           'CLAGE','NINQ','CLNO', 'DEBTINC'])}
print("Listado de atributos\n====================")
for feature in feature_map:
    print("- %s" % feature)
# Out:
# Listado de atributos
# ====================
# - LOAN
# - MORTDUE
# - VALUE
# - YOJ
# - DEROG
# - DELINQ
# - CLAGE
# - NINQ
# - CLNO
# - DEBTINC

# %% [markdown]
# ## Ejercicio 2: Elección de un modelo
#
# Basándose en lo visto en el teórico escojan y justifiquen un modelo de aprendizaje automático. Recuerden que los pasos para elegir un modelo son:
#
# ### Selección de hipótesis
#
# Utilizaremos regresión logística, con función:
#
# $$h_w(x)= \frac{1}{1+\exp(-w^T x))}$$
#
# ### Selección de regularizador
#
# Analizaremos cual de los dos regularizadores (L1 y L2) nos devuelve mejores resultados.
#
# ### Selección de función de coste
#
# $$L(w)=- \sum_{i=1}^N y_i \log (h_w(x_i)) + (1-y_i) \log (1-h_w(x_i))$$
#
# ### Justificación de las selecciones
#
# Es un problema de clasificación binaria, y elegimos la regresión logística como hipótesis, ya que la salida tomará valores de 0 / 1. La regresión será de atributos regulares, utilizando todos los features del dataset. Decidimos esto debido a que previamente combinamos distintos features para intentar probar que el conjunto de datos sea linealmente separable pero no nos fue posible, lo que nos llevo a encontrar que usando todas las features mejorábamos la exactitud. En cuanto a los regularizadores, vimos que ambos presentaron un rendimiento similar para este caso de análisis, por lo que escojeremos al regularizador L2 debido a que generalmente es el más utilizado por su mejor rendimiento.

# %% [markdown]
# ## Ejercicio 3: Selección de hiperparámetros
#
# Utilizando búsqueda exhaustiva (*grid search*) con *5-fold cross-validation* y utilizando como métrica el área bajo la curva de ROC (o *ROC-AUC*), hagan una selección de los mejores hiperparámetros para su conjunto de datos y el modelo que hayan elegido en el apartado anterior.

# %%
plt.figure(figsize=(20, 10), dpi= 80, facecolor='w', edgecolor='k')
  
for idx, penalty in enumerate(('l1', 'l2'), start=1):
    exploring_params = {
        'C': [1./40., 1./30., 1./20., 1./10., 1./1., 1./0.9, 1./0.8, 1./0.5, 1./0.1, 1./0.01],  # Tasa de regularización
        'tol': [1e-3, 1e-5], 
        'max_iter': [10000, 15000, 20000]
    }  
    
    m = LogisticRegression(penalty=penalty)
    model = GridSearchCV(m, exploring_params, cv=5, scoring='roc_auc')
    model.fit(X_train, y_train)
    
    print("####################################################################")
    print("    Exploración de hiperparámetros para función de coste \"%s\"    " % penalty, end="\n")
    print("####################################################################\n")
    
    print("Mejor conjunto de parámetros:")
    print(model.best_params_, end="\n\n")

    print("Puntajes de la grilla:", end="\n")
    means = model.cv_results_['mean_test_score']
    stds = model.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, model.cv_results_['params']):
        print("Exactitud: %0.3f (+/-%0.03f) para los parámetros %r" % (mean, std ** 2, params))
    print()

    print("Reporte de clasificación para el mejor clasificador (sobre conjunto de evaluación):", end="\n")
    y_true, y_pred = y_test, model.predict(X_test)
    print(classification_report(y_true, y_pred), end="\n\n")
    
    print("==================================================================================", end="\n\n")

    plt.subplot(1, 2, idx)
    plot_confusion_matrix(confusion_matrix(y_true, y_pred),
                          classes=[0,1], title="Matriz de confusión para %s" % penalty)
# Out:
# ####################################################################
#     Exploración de hiperparámetros para función de coste "l1"
# ####################################################################
#
# Mejor conjunto de parámetros:
# {'C': 0.1, 'max_iter': 15000, 'tol': 1e-05}
#
# Puntajes de la grilla:
# Exactitud: 0.757 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.757 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.757 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.757 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.756 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.756 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.762 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.762 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.762 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.762 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.762 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.762 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.768 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.790 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.791 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.788 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.791 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.791 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.791 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.790 (+/-0.003) para los parámetros {'C': 1.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.791 (+/-0.003) para los parámetros {'C': 1.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.0, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.790 (+/-0.003) para los parámetros {'C': 1.1111111111111112, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.789 (+/-0.002) para los parámetros {'C': 1.1111111111111112, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.1111111111111112, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.789 (+/-0.002) para los parámetros {'C': 1.1111111111111112, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.790 (+/-0.003) para los parámetros {'C': 1.1111111111111112, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.789 (+/-0.002) para los parámetros {'C': 1.1111111111111112, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.25, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 1.25, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.25, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 1.25, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 1.25, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 1.25, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.002) para los parámetros {'C': 2.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 2.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.002) para los parámetros {'C': 2.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 2.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 2.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 2.0, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 10.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.787 (+/-0.002) para los parámetros {'C': 10.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 10.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.787 (+/-0.002) para los parámetros {'C': 10.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.788 (+/-0.002) para los parámetros {'C': 10.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.787 (+/-0.002) para los parámetros {'C': 10.0, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 100.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.786 (+/-0.002) para los parámetros {'C': 100.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.787 (+/-0.002) para los parámetros {'C': 100.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.786 (+/-0.002) para los parámetros {'C': 100.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.789 (+/-0.003) para los parámetros {'C': 100.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.786 (+/-0.002) para los parámetros {'C': 100.0, 'max_iter': 20000, 'tol': 1e-05}
#
# Reporte de clasificación para el mejor clasificador (sobre conjunto de evaluación):
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93       477
#           1       0.65      0.28      0.39        80
#
# avg / total       0.85      0.87      0.85       557
#
#
# ==================================================================================
#
# ####################################################################
#     Exploración de hiperparámetros para función de coste "l2"
# ####################################################################
#
# Mejor conjunto de parámetros:
# {'C': 1.1111111111111112, 'max_iter': 10000, 'tol': 1e-05}
#
# Puntajes de la grilla:
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.773 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.773 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.773 (+/-0.004) para los parámetros {'C': 0.025, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.767 (+/-0.004) para los parámetros {'C': 0.03333333333333333, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.775 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.775 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.775 (+/-0.004) para los parámetros {'C': 0.05, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.004) para los parámetros {'C': 0.1, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.784 (+/-0.004) para los parámetros {'C': 1.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.784 (+/-0.004) para los parámetros {'C': 1.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.784 (+/-0.004) para los parámetros {'C': 1.0, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.1111111111111112, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.784 (+/-0.003) para los parámetros {'C': 1.1111111111111112, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.1111111111111112, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.784 (+/-0.003) para los parámetros {'C': 1.1111111111111112, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.1111111111111112, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.784 (+/-0.003) para los parámetros {'C': 1.1111111111111112, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.25, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.003) para los parámetros {'C': 1.25, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.25, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.003) para los parámetros {'C': 1.25, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 1.25, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.003) para los parámetros {'C': 1.25, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 2.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.003) para los parámetros {'C': 2.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 2.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.003) para los parámetros {'C': 2.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 2.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.777 (+/-0.003) para los parámetros {'C': 2.0, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 10.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.783 (+/-0.003) para los parámetros {'C': 10.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 10.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.783 (+/-0.003) para los parámetros {'C': 10.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 10.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.783 (+/-0.003) para los parámetros {'C': 10.0, 'max_iter': 20000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 100.0, 'max_iter': 10000, 'tol': 0.001}
# Exactitud: 0.781 (+/-0.004) para los parámetros {'C': 100.0, 'max_iter': 10000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 100.0, 'max_iter': 15000, 'tol': 0.001}
# Exactitud: 0.781 (+/-0.004) para los parámetros {'C': 100.0, 'max_iter': 15000, 'tol': 1e-05}
# Exactitud: 0.632 (+/-0.004) para los parámetros {'C': 100.0, 'max_iter': 20000, 'tol': 0.001}
# Exactitud: 0.781 (+/-0.004) para los parámetros {'C': 100.0, 'max_iter': 20000, 'tol': 1e-05}
#
# Reporte de clasificación para el mejor clasificador (sobre conjunto de evaluación):
#              precision    recall  f1-score   support
#
#           0       0.89      0.97      0.93       477
#           1       0.61      0.29      0.39        80
#
# avg / total       0.85      0.87      0.85       557
#
#
# ==================================================================================

# %% [markdown]
# ## Ejercicio 4: Métricas sobre el conjunto de evaluación
#
# Una vez encontrados los mejores hiperparámetros para el modelo seleccionado en los apartados anteriores se evalúa el modelo final entrenado sobre el conjunto de datos de evaluación seleccionado en el ejercicio 1. Pueden utilizar las métricas que crean convenientes. Es mejor utilizar más de una métrica. Particularmente el *reporte de clasificación* y la *matriz de confusión* son buenos ejemplos de métricas.

# %%
# Parametros determinados en el punto anterior:
penalty = 'l2' 
C = 1./0.9      
max_iter = 10000 
tol = 1e-05     

model = LogisticRegression(penalty=penalty, C=C, max_iter=max_iter, tol=tol, solver='newton-cg')
model.fit(X_train, y_train)

# Evaluamos el desempeño del clasificador utilizando la exactitud (accuracy) sobre el conjunto
# de datos de entrenamiento (X_train, y_train) y lo comparamos con el de validación (X_test, y_test)
# La exactitud toma valor en el rango [0, 1] donde más alto es mejor
print('Exactitud para entrenamiento: %.2f' %  accuracy_score(y_train, model.predict(X_train)))
print('Exactitud para validación: %.2f' % accuracy_score(y_test, model.predict(X_test)))
# Out:
# Exactitud para entrenamiento: 0.87
# Exactitud para validación: 0.88

# %% [markdown]
# ### Matriz de confusión

# %%
plt.figure(figsize=(14, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(2, 2, 1)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train)),
                classes=[0,1],title='Matriz de confusión para entrenamiento (sin normalizar)')
plt.subplot(2, 2, 3)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train)),
                classes=[0,1],normalize=True,title='Matriz de confusión para entrenamiento (normalizando)')

plt.subplot(2,2,2)
plot_confusion_matrix(confusion_matrix(y_test, model.predict(X_test)), 
                      classes=[0,1], title="Matriz de confusión para validación (sin normalizar)")

plt.subplot(2, 2, 4)
plot_confusion_matrix(confusion_matrix(y_test, model.predict(X_test)),
                classes=[0,1], normalize=True,title='Matriz de confusión para validación (normalizando)')
plt.show();

# %% [markdown]
# ### Reporte de clasificación

# %%
print("Reporte de clasificación para el mejor clasificador (sobre conjunto de entrenamiento):", end="\n")
y_true, y_pred = y_train, model.predict(X_train)
print(classification_report(y_true, y_pred), end="\n\n")
    
print("==================================================================================", end="\n\n")

print("Reporte de clasificación para el mejor clasificador (sobre conjunto de evaluación):", end="\n")
y_true, y_pred = y_test, model.predict(X_test)
print(classification_report(y_true, y_pred), end="\n\n")
    
print("==================================================================================", end="\n\n")
# Out:
# Reporte de clasificación para el mejor clasificador (sobre conjunto de entrenamiento):
#              precision    recall  f1-score   support
#
#           0       0.87      0.98      0.93      1068
#           1       0.81      0.34      0.48       229
#
# avg / total       0.86      0.87      0.85      1297
#
#
# ==================================================================================
#
# Reporte de clasificación para el mejor clasificador (sobre conjunto de evaluación):
#              precision    recall  f1-score   support
#
#           0       0.90      0.97      0.93       477
#           1       0.63      0.34      0.44        80
#
# avg / total       0.86      0.88      0.86       557
#
#
# ==================================================================================

# %% [markdown]
# ## Ejercicio 5 (opcional): Curvas de ROC
#
# Como ejercicio adicional (opcional), pueden redefinir el umbral de decisión óptimo del problema a partir de los resultados que muestren curvas de ROC como justificación.
#
# Pueden ver esto mediante la [graficación de las curvas de ROC](http://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html). En el link que se les brinda se muestra como hacer para graficar curvas de ROC para problemas multiclase. Sin embargo se puede adaptar fácilmente a un problema binario obviando la parte donde se calcula la curva clase por clase.
